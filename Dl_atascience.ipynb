# %% [markdown]
# <a href="https://colab.research.google.com/github/HARAJIT05/Datascience_MCA/blob/main/Dl_atascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/DrTNPaul/T20-World-Cup-2026.git
# Out:
# Cloning into 'T20-World-Cup-2026'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), 195.45 KiB | 17.77 MiB/s, done.

# %%
import os
os.listdir('/content/T20-World-Cup-2026')
# Out:
# ['.git', 'MatchResults refined .xlsx', 'Batting_fixed.csv', 'Batting.csv']

# %%
import pandas as pd
df_batting = pd.read_csv('/content/T20-World-Cup-2026/Batting_fixed.csv')
half_century = df_batting[(pd.to_numeric(df_batting['R']) >= 50) & (pd.to_numeric(df_batting['R']) < 100)]
print(f"Total number of players who scored Half Century: {len(half_century)}")
# Out:
# Total number of players who scored Half Century: 73

# %%
total_countries = df_batting['Team'].unique().tolist()
print(len(total_countries))
# Out:
# 20
