# %% [markdown]
# <a href="https://colab.research.google.com/github/HARAJIT05/Datascience_MCA/blob/main/Dl_atascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/HARAJIT05/DATASETS-DATASCIENCE.git
# Out:
# fatal: destination path 'DATASETS-DATASCIENCE' already exists and is not an empty directory.

# %%
import os
os.listdir('/content/DATASETS-DATASCIENCE')
# Out:
# ['MatchResults-refined-Batting.csv',
#  '.git',
#  'MatchResults refined-TeamBat.csv',
#  'MatchResults refined-Bowling.csv',
#  'Batting_fixed.csv',
#  'MatchResults-refined.xlsx']

# %% [markdown]
# Half Century

# %%
import pandas as pd
df_batting = pd.read_csv('/content/DATASETS-DATASCIENCE/Batting_fixed.csv')
half_century = df_batting[(pd.to_numeric(df_batting['R']) >= 50) & (pd.to_numeric(df_batting['R']) < 100)]
print(f"Total number of players who scored Half Century: {len(half_century)}")
# Out:
# Total number of players who scored Half Century: 73

# %% [markdown]
# TOTAL TEAM

# %%
total_countries = df_batting['Team'].unique().tolist()
print(len(total_countries))
# Out:
# 20

# %% [markdown]
# AVG Score

# %%
avg_score=df_batting.groupby('Team')['R'].mean()
print(avg_score)
# Out:
# Team
# Afghanistan     22.290323
# Australia       18.272727
# Canada          16.085714
# England         18.200000
# India           19.127273
# Ireland         16.517241
# Italy           15.735294
# Namibia         12.033333
# Nepal           16.600000
# Netherlands     13.193548
# New Zealand     25.769231
# Oman             9.727273
# Pakistan        19.403846
# Scotland        17.324324
# South Africa    28.333333
# Sri Lanka       22.239130
# UAE             17.562500
# USA             20.000000
# West Indies     23.977273
# Zimbabwe        22.029412
# Name: R, dtype: float64

# %% [markdown]
# TOTAL 4s and 6s

# %%
total_boundry=df.groupby("Team")[['4s','6s']].sum().reset_index().sort_values(by=['4s','6s'],ascending=True)
print(total_boundry)
# Out:
#             Team  4s  6s
# 8          Nepal  26  18
# 7        Namibia  29  11
# 6          Italy  38  34
# 9    Netherlands  42   9
# 11          Oman  42   9
# 5        Ireland  42  19
# 17           USA  45  33
# 0    Afghanistan  47  34
# 16           UAE  48  23
# 2         Canada  54  20
# 13      Scotland  58  26
# 1      Australia  61  18
# 3        England  66  37
# 19      Zimbabwe  75  31
# 18   West Indies  83  66
# 4          India  86  65
# 14  South Africa  89  51
# 10   New Zealand  90  47
# 12      Pakistan  92  46
# 15     Sri Lanka  97  34

# %% [markdown]
# TOTAL DOT BALLS THROWN BY EVERY COUNTRY

# %%
import pandas as pd

df_bowling = pd.read_csv('/content/DATASETS-DATASCIENCE/MatchResults refined-Bowling.csv')

df_bowling['Dots'] = pd.to_numeric(df_bowling['Dots'], errors='coerce').fillna(0).astype(int)

dot_balls_by_country = df_bowling.groupby('Team')['Dots'].sum().reset_index()
dot_balls_by_country.columns = ['Country Name', 'Total Dot Balls']

dot_balls_by_country = dot_balls_by_country.sort_values(by='Total Dot Balls', ascending=False)

display(dot_balls_by_country)
# Out:
#     Country Name  Total Dot Balls
# 12      Pakistan              313
# 4          India              300
# 18   West Indies              287
# 15     Sri Lanka              274
# 14  South Africa              273
# 10   New Zealand              255
# 9     Netherland              216
# 3        England              206
# 0     Afganistan              191
# 6          Italy              174
# 1      Australia              172
# 17           USA              169
# 19      Zimbabwe              164
# 2         Canada              147
# 11          Oman              146
# 7        Namibia              141
# 13      Scotland              131
# 16           UAE              121
# 5        Ireland              115
# 8          Nepal              107

# %% [markdown]
# ### Total Wins and Losses by Country

# %%
import pandas as pd

df_batting_fixed = pd.read_csv('/content/DATASETS-DATASCIENCE/Batting_fixed.csv')

match_outcomes = df_batting_fixed.groupby(['Team', 'Date'])['Win'].max().reset_index()

win_loss_summary = match_outcomes.groupby('Team')['Win'].agg(
    Wins=lambda x: (x == 1).sum(),
    Losses=lambda x: (x == 0).sum()
).reset_index()

display(win_loss_summary.sort_values(by='Wins', ascending=False))
# Out:
#             Team  Wins  Losses
# 14  South Africa     6       0
# 4          India     5       1
# 18   West Indies     5       1
# 3        England     4       1
# 12      Pakistan     4       2
# 10   New Zealand     4       2
# 19      Zimbabwe     3       2
# 15     Sri Lanka     3       3
# 0    Afghanistan     2       2
# 1      Australia     2       2
# 17           USA     2       2
# 5        Ireland     1       2
# 16           UAE     1       3
# 6          Italy     1       3
# 13      Scotland     1       3
# 8          Nepal     1       2
# 2         Canada     0       4
# 11          Oman     0       4
# 7        Namibia     0       3
# 9    Netherlands     0       3
